# %% [markdown]
# # Aufgaben für den 21.04.2026
#
# Quelle: hochgeladenes PDF.

# %% [markdown]
# ## Aufgabe 1
#
# Bei einer Untersuchung von 1000 Männern werden die Größe und die Haarfarbe verglichen.
#
# Das Ereignis **G** bedeutet eine Größe von mehr als 1,90 m.
#
# Das Ereignis **B** bedeutet, dass die ausgewählte Person braune Haare hat.
#
# 40% der Männer sind über 1,90 m groß, 70% der Männer haben braune Haare. 70% der Männer unter 1,90 m haben braune Haare.
#
# Untersuchen Sie, ob die Haarfarbe von der Größe stochastisch abhängig ist!

# %%
p_g = 0.4
p_b = 0.7
p_b_bed_nicht_g = 0.7

gesamt = 1000
g = p_g*gesamt
nicht_g = gesamt-g

b_nicht_g = p_b_bed_nicht_g * nicht_g
b_gesamt = p_b * gesamt

b_g = b_gesamt - b_nicht_g

p_b_bed_g = b_g/g

print(f"{(p_g == p_b_bed_g)}")
# Out:
# False

# %% [markdown]
# ## Aufgabe 2
#
# Gegeben ist die diskrete Zufallsvariable $X$, die die Werte $1, 2, 3, 4$ annehmen kann.
#
# Es sei
#
# $$
# P(X = k) =
# \begin{cases}
# \dfrac{k(b-k)}{20} & \text{für } k \in \{1,2,3,4\} \\
# 0 & \text{sonst}
# \end{cases}
# $$
#
# **(a)** Wie muss $b$ lauten?
#
# **(b)** Bestimmen Sie $P(X=2)$
#
# **(c)** Bestimmen Sie $P(2<X<4)$
#
# **(d)** Bestimmen Sie $P(X>3)$

# %%
print("a) Siehe Heft: b = 5")
k=2
b=5
print(f"b) P(X=2) = {(k*(b-k))/20}")
print(f"c) P(2<X<4) = {sum(((x*(b-x))/20) for x in [3] )}")
k=4
print(f"d) P(X>3) = {(k*(b-k))/20}")
# Out:
# a) Siehe Heft: b = 5
# b) P(X=2) = 0.3
# c) P(2<X<4) = 0.3
# d) P(X>3) = 0.2

# %% [markdown]
# ## Aufgabe 3
#
# Es sei $X$ eine Zufallsvariable mit Dichtefunktion
#
# $$
# f(t) =
# \begin{cases}
# c \cdot t^{-5} & \text{für } t > 1 \\
# 0 & \text{sonst}
# \end{cases}
# $$
#
# **(a)** Bestimmen Sie $c$
#
# **(b)** Bestimmen Sie $P(X=2)$
#
# **(c)** Bestimmen Sie $P(2<X<4)$
#
# **(d)** Bestimmen Sie $P(X>3)$

# %%
c = 4
print(f"a) Rechenweg siehe heft: c = {4} ")
t = 2
print(f"b) P(X = 2) = {c*t**(-5)}")
t=3
print(f"c) P(2 < X < 4) = {c*t**(-5)}")
print(f"d) P(X>3) = {sum(c*t**(-5) for t in range(4,999999))}")
# Out:
# a) Rechenweg siehe heft: c = 4
# b) P(X = 2) = 0.125
# c) P(2 < X < 4) = 0.01646090534979424
# d) P(X>3) = 0.006250115223684955
